# %% [markdown]
# # PID Controllers
# In this notebook, we explore the PID controllers by explaining the underlying theory and by providing a simulation of a second order system to practice PID gain parameter tuning.

# %%
# %matplotlib notebook

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import signal
from control import *

# %%
# Plant
num = [1]
den = [1, 10, 20]
G = tf(num, den)
H = [1]
w, mag, phase = bode(G)

t, s = step_response(G)
plt.figure()
plt.plot(t,s)
plt.ylabel(r'Magnitude')
plt.xlabel(r'Time (sec)')
plt.grid()
plt.show

#PID Controller
Kp = 300
Ki = 0
Kd = 0

pid_num = [Kd, Kp, Ki]
pid_den = [1, 0]
C = tf(pid_num,pid_den)

# System
T = feedback(C*G,1)

t, s = step_response(T)
plt.figure()
plt.plot(t,s)
plt.ylabel(r'Magnitude')
plt.xlabel(r'Time (sec)')
plt.grid()
plt.show
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <function matplotlib.pyplot.show>
